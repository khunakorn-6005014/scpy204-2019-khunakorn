# %%
Demonstrating how to use python

# %%
import pandas as pd
df = pd.read_csv("Documents/physics/com/hw2week3/covid1.csv")
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      12/04/2020   12      4  2020     34       3             Afghanistan
# 1      11/04/2020   11      4  2020     37       0             Afghanistan
# 2      10/04/2020   10      4  2020     61       1             Afghanistan
# 3      09/04/2020    9      4  2020     56       3             Afghanistan
# 4      08/04/2020    8      4  2020     30       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 10327  25/03/2020   25      3  2020      0       0                Zimbabwe
# 10328  24/03/2020   24      3  2020      0       1                Zimbabwe
# 10329  23/03/2020   23      3  2020      0       0                Zimbabwe
# 10330  22/03/2020   22      3  2020      1       0                Zimbabwe
# 10331  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018
# ...

# %%
df.query('countriesAndTerritories == ["Thailand"]')
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 9427  12/04/2020   12      4  2020     33       3                Thailand
# 9428  11/04/2020   11      4  2020     45       2                Thailand
# 9429  10/04/2020   10      4  2020     50       1                Thailand
# 9430  09/04/2020    9      4  2020     54       2                Thailand
# 9431  08/04/2020    8      4  2020    111       4                Thailand
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9519  04/01/2020    4      1  2020      0       0                Thailand
# 9520  03/01/2020    3      1  2020      0       0                Thailand
# 9521  02/01/2020    2      1  2020      0       0                Thailand
# 9522  01/01/2020    1      1  2020      0       0                Thailand
# 9523  31/12/2019   31     12  2019      0       0                Thailand
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
deathThailand=df.query("countriesAndTerritories == ['Thailand']")['deaths'].sum()
deathThailand
# Out:
# 38

# %%
casesThailand=df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()
casesThailand
# Out:
# 2551

# %%
peoplethai=df.query("countriesAndTerritories == ['Thailand']")['popData2018'].mean()
peoplethai
# Out:
# 69428524.0

# %%
percentCasestoPeople=100*df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()/df.query("countriesAndTerritories == ['Thailand']")['popData2018'].mean()
percentCasestoPeople
# Out:
# 0.003674282345394524

# %%
percentDeathtoCases=100*df.query("countriesAndTerritories == ['Thailand']")['deaths'].sum()/df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()
percentDeathtoCases
# Out:
# 1.4896119168953352

# %%
df1=df[:27]
df1.plot('dateRep',[4,5],kind = 'line')

# %%
df.query('countriesAndTerritories == ["Thailand","China","Italy","Japan","Germany","India","Singapore","South_Korea","United_States_of_America","United_Kingdom","Iran"]')
# Out:
#           dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 2009   12/04/2020   12      4  2020     93       0                     China
# 2010   11/04/2020   11      4  2020     79       3                     China
# 2011   10/04/2020   10      4  2020     55       1                     China
# 2012   09/04/2020    9      4  2020     86       2                     China
# 2013   08/04/2020    8      4  2020     86       2                     China
# ...           ...  ...    ...   ...    ...     ...                       ...
# 10071  04/01/2020    4      1  2020      0       0  United_States_of_America
# 10072  03/01/2020    3      1  2020      0       0  United_States_of_America
# 10073  02/01/2020    2      1  2020      0       0  United_States_of_America
# 10074  01/01/2020    1      1  2020      0       0  United_States_of_America
# 10075  31/12/2019   31     12  2019      0       0  United_States_of_America
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Documents/physics/com/hw2week3/covid1.csv")
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      12/04/2020   12      4  2020     34       3             Afghanistan
# 1      11/04/2020   11      4  2020     37       0             Afghanistan
# 2      10/04/2020   10      4  2020     61       1             Afghanistan
# 3      09/04/2020    9      4  2020     56       3             Afghanistan
# 4      08/04/2020    8      4  2020     30       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 10327  25/03/2020   25      3  2020      0       0                Zimbabwe
# 10328  24/03/2020   24      3  2020      0       1                Zimbabwe
# 10329  23/03/2020   23      3  2020      0       0                Zimbabwe
# 10330  22/03/2020   22      3  2020      1       0                Zimbabwe
# 10331  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018
# ...

# %%
df.query('countriesAndTerritories == ["Thailand"]')
df.plot(x='dateRep' , y= 'cases' , kind= 'line')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-208bab2aadeb> in <module>
# ----> 1 df.query('countriesAndTerritories == ["Thailand"]')
#       2 df.plot(x='dateRep' , y= 'cases' , kind= 'line')
#
# NameError: name 'df' is not defined

# %%
df.query('countriesAndTerritories == ["Thailand","China","Italy","Japan","Germany","India","Singapore","South_Korea","United_States_of_America","United_Kingdom","Iran"]')
df.plot(x='dateRep' , y='cases' , kind='line')

# %%
data=df.query('countriesAndTerritories == ["Thailand"]')
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 9427  12/04/2020   12      4  2020     33       3                Thailand
# 9428  11/04/2020   11      4  2020     45       2                Thailand
# 9429  10/04/2020   10      4  2020     50       1                Thailand
# 9430  09/04/2020    9      4  2020     54       2                Thailand
# 9431  08/04/2020    8      4  2020    111       4                Thailand
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9519  04/01/2020    4      1  2020      0       0                Thailand
# 9520  03/01/2020    3      1  2020      0       0                Thailand
# 9521  02/01/2020    2      1  2020      0       0                Thailand
# 9522  01/01/2020    1      1  2020      0       0                Thailand
# 9523  31/12/2019   31     12  2019      0       0                Thailand
#
#      geoId countryterritoryCode  popData2018
# ...
