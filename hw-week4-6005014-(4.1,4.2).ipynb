# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
url='Documents/physics/com/hw2week3/covid1.csv'
df=pd.read_csv(url)
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      12/04/2020   12      4  2020     34       3             Afghanistan
# 1      11/04/2020   11      4  2020     37       0             Afghanistan
# 2      10/04/2020   10      4  2020     61       1             Afghanistan
# 3      09/04/2020    9      4  2020     56       3             Afghanistan
# 4      08/04/2020    8      4  2020     30       4             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 10327  25/03/2020   25      3  2020      0       0                Zimbabwe
# 10328  24/03/2020   24      3  2020      0       1                Zimbabwe
# 10329  23/03/2020   23      3  2020      0       0                Zimbabwe
# 10330  22/03/2020   22      3  2020      1       0                Zimbabwe
# 10331  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2018
# ...

# %%
url='Documents/physics/com/hw2week3/covid1.csv'
df=pd.read_csv(url, index_col=['countriesAndTerritories','dateRep'])
df
# Out:
#                                     day  month  year  cases  deaths geoId  \
# countriesAndTerritories dateRep
# Afghanistan             12/04/2020   12      4  2020     34       3    AF
#                         11/04/2020   11      4  2020     37       0    AF
#                         10/04/2020   10      4  2020     61       1    AF
#                         09/04/2020    9      4  2020     56       3    AF
#                         08/04/2020    8      4  2020     30       4    AF
# ...                                 ...    ...   ...    ...     ...   ...
# Zimbabwe                25/03/2020   25      3  2020      0       0    ZW
#                         24/03/2020   24      3  2020      0       1    ZW
#                         23/03/2020   23      3  2020      0       0    ZW
#                         22/03/2020   22      3  2020      1       0    ZW
#                         21/03/2020   21      3  2020      1       0    ZW
#
# ...

# %%
jj=df.loc['Thailand']
jj
# Out:
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020     33       3    TH                  THA
# 11/04/2020   11      4  2020     45       2    TH                  THA
# 10/04/2020   10      4  2020     50       1    TH                  THA
# 09/04/2020    9      4  2020     54       2    TH                  THA
# 08/04/2020    8      4  2020    111       4    TH                  THA
# ...         ...    ...   ...    ...     ...   ...                  ...
# 04/01/2020    4      1  2020      0       0    TH                  THA
# 03/01/2020    3      1  2020      0       0    TH                  THA
# 02/01/2020    2      1  2020      0       0    TH                  THA
# 01/01/2020    1      1  2020      0       0    TH                  THA
# 31/12/2019   31     12  2019      0       0    TH                  THA
#
#             popData2018
# dateRep
# 12/04/2020   69428524.0
# 11/04/2020   69428524.0
# ...

# %%
plt.figure(figsize=(10,10))
jj['cases'].plot(kind='line', title='thailand')

# %%
gt=df.query('countriesAndTerritories == ["Thailand","China","Italy","Japan","Germany","India","Singapore","South_Korea","United_States_of_America","United_Kingdom","Iran"]')
gt
# Out:
#                                      day  month  year  cases  deaths geoId  \
# countriesAndTerritories  dateRep
# China                    12/04/2020   12      4  2020     93       0    CN
#                          11/04/2020   11      4  2020     79       3    CN
#                          10/04/2020   10      4  2020     55       1    CN
#                          09/04/2020    9      4  2020     86       2    CN
#                          08/04/2020    8      4  2020     86       2    CN
# ...                                  ...    ...   ...    ...     ...   ...
# United_States_of_America 04/01/2020    4      1  2020      0       0    US
#                          03/01/2020    3      1  2020      0       0    US
#                          02/01/2020    2      1  2020      0       0    US
#                          01/01/2020    1      1  2020      0       0    US
#                          31/12/2019   31     12  2019      0       0    US
#
# ...

# %%
plt.figure(figsize=(20,20))
plt.xlabel('Daterep')
plt.ylabel('cases(numbers)')
plt.title('relation between global covid-19 cases and time')
df.loc[['Thailand'],'cases'].plot(x='dateRep',y='Thai',kind='line',color='red',legend='thailand')
df.loc[['China'],'cases'].plot(x='dateRep',y='China',kind='line',color='orange',legend='china')
df.loc[['Japan'],'cases'].plot(x='dateRep',y='cases',kind='line',color='gold',legend='japan')
df.loc[['Germany '],'cases'].plot(x='dateRep',y='cases',kind='line',color='green',legend='germany')
df.loc[['India '],'cases'].plot(x='dateRep',y='cases',kind='line',color='aqua',legend='india')
df.loc[['Singapore '],'cases'].plot(x='dateRep',y='cases',kind='line',color='dodgerblue',legend='singapore')
df.loc[['Iran'],'cases'].plot(x='dateRep',y='cases',kind='line',color='blue',legend='iran')
df.loc[['South_Korea '],'cases'].plot(x='dateRep',y='cases',kind='line',color='magenta',legend='South korea')
df.loc[['United_States_of_America'],'cases'].plot(x='dateRep',y='cases',kind='line',color='purple',legend='USA')
df.loc[['United_Kingdom'],'cases'].plot(x='dateRep',y='cases',kind='line',color='black',legend='UK')

# %%
gt.loc[['Thailand','China'],'cases']
# Out:
# countriesAndTerritories  dateRep
# China                    12/04/2020    93
#                          11/04/2020    79
#                          10/04/2020    55
#                          09/04/2020    86
#                          08/04/2020    86
#                                        ..
# Thailand                 04/01/2020     0
#                          03/01/2020     0
#                          02/01/2020     0
#                          01/01/2020     0
#                          31/12/2019     0
# Name: cases, Length: 201, dtype: int64

# %%
plt.figure(figsize=(16,9))
plot(x='dateRep', y='cases', data='df.loc[['Thailand'],'cases']', kind='line')
# Out:
#   File "<ipython-input-117-d68e3d1f38c5>", line 2
#     plot(x='dateRep', y='cases', data='df.loc[['Thailand'],'cases']', kind='line')
#                                                        ^
# SyntaxError: invalid syntax

# %%
sns.lineplot(data='[df.log[['Thailand'],'cases']]')
# Out:
#   File "<ipython-input-131-a9a606973bc2>", line 1
#     sns.lineplot(data='[df.log[['Thailand'],'cases']]')
#                                         ^
# SyntaxError: invalid syntax

# %%
rt=df.loc[['Thailand','China'],'cases']
rt
# Out:
# countriesAndTerritories  dateRep
# China                    12/04/2020    93
#                          11/04/2020    79
#                          10/04/2020    55
#                          09/04/2020    86
#                          08/04/2020    86
#                                        ..
# Thailand                 04/01/2020     0
#                          03/01/2020     0
#                          02/01/2020     0
#                          01/01/2020     0
#                          31/12/2019     0
# Name: cases, Length: 201, dtype: int64

# %%
ax=rt.plot(kind='line', color='gold' , legend='china')
ax.set_xlabel('')
ax.set_ylabel('cases')
# Out:
# Text(0, 0.5, 'cases')

# %%
df=pd.read_csv(url, index_col=['countriesAndTerritories','dateRep'])
df
# Out:
#                                     day  month  year  cases  deaths geoId  \
# countriesAndTerritories dateRep
# Afghanistan             12/04/2020   12      4  2020     34       3    AF
#                         11/04/2020   11      4  2020     37       0    AF
#                         10/04/2020   10      4  2020     61       1    AF
#                         09/04/2020    9      4  2020     56       3    AF
#                         08/04/2020    8      4  2020     30       4    AF
# ...                                 ...    ...   ...    ...     ...   ...
# Zimbabwe                25/03/2020   25      3  2020      0       0    ZW
#                         24/03/2020   24      3  2020      0       1    ZW
#                         23/03/2020   23      3  2020      0       0    ZW
#                         22/03/2020   22      3  2020      1       0    ZW
#                         21/03/2020   21      3  2020      1       0    ZW
#
# ...

# %%
jj
# Out:
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020     33       3    TH                  THA
# 11/04/2020   11      4  2020     45       2    TH                  THA
# 10/04/2020   10      4  2020     50       1    TH                  THA
# 09/04/2020    9      4  2020     54       2    TH                  THA
# 08/04/2020    8      4  2020    111       4    TH                  THA
# ...         ...    ...   ...    ...     ...   ...                  ...
# 04/01/2020    4      1  2020      0       0    TH                  THA
# 03/01/2020    3      1  2020      0       0    TH                  THA
# 02/01/2020    2      1  2020      0       0    TH                  THA
# 01/01/2020    1      1  2020      0       0    TH                  THA
# 31/12/2019   31     12  2019      0       0    TH                  THA
#
#             popData2018
# dateRep
# 12/04/2020   69428524.0
# 11/04/2020   69428524.0
# ...

# %%
jj['cases/people']=100*df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()/df.query("countriesAndTerritories == ['Thailand']")['popData2018'].mean()
jj['death/cases']=100*df.query("countriesAndTerritories == ['Thailand']")['deaths'].sum()/df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()
jj
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020     33       3    TH                  THA
# ...

# %%
oo=df.loc['China']

# %%
oo['cases/people']=100*df.query("countriesAndTerritories == ['China'] ")['cases'].sum()/df.query("countriesAndTerritories == ['China']")['popData2018'].mean()
oo['death/cases']=100*df.query("countriesAndTerritories == ['China']")['deaths'].sum()/df.query("countriesAndTerritories == ['China']")['cases'].sum()
oo
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020     93       0    CN                  CHN
# ...

# %%
ww=df.loc['Japan']

# %%
ww['cases/people']=100*df.query("countriesAndTerritories == ['Japan'] ")['cases'].sum()/df.query("countriesAndTerritories == ['Japan']")['popData2018'].mean()
ww['death/cases']=100*df.query("countriesAndTerritories == ['Japan']")['deaths'].sum()/df.query("countriesAndTerritories == ['Japan']")['cases'].sum()
ww
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020   1401      10    JP                  JPN
# ...

# %%
ee=df.loc['Italy']

# %%
ee['cases/people']=100*df.query("countriesAndTerritories == ['Italy'] ")['cases'].sum()/df.query("countriesAndTerritories == ['Italy']")['popData2018'].mean()
ee['death/cases']=100*df.query("countriesAndTerritories == ['Italy']")['deaths'].sum()/df.query("countriesAndTerritories == ['Italy']")['cases'].sum()
ee
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020   4694     619    IT                  ITA
# ...

# %%
rr=df.loc['Germany']

# %%
rr['cases/people']=100*df.query("countriesAndTerritories == ['Germany'] ")['cases'].sum()/df.query("countriesAndTerritories == ['Germany']")['popData2018'].mean()
rr['death/cases']=100*df.query("countriesAndTerritories == ['Germany']")['deaths'].sum()/df.query("countriesAndTerritories == ['Germany']")['cases'].sum()
rr
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020   2821     129    DE                  DEU
# ...

# %%
tt=df.loc['India']

# %%
tt['cases/people']=100*df.query("countriesAndTerritories == ['India'] ")['cases'].sum()/df.query("countriesAndTerritories == ['India']")['popData2018'].mean()
tt['death/cases']=100*df.query("countriesAndTerritories == ['India']")['deaths'].sum()/df.query("countriesAndTerritories == ['India']")['cases'].sum()
tt
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020    909      34    IN                  IND
# ...

# %%
yy=df.loc['Singapore']

# %%
yy['cases/people']=100*df.query("countriesAndTerritories == ['Singapore'] ")['cases'].sum()/df.query("countriesAndTerritories == ['Singapore']")['popData2018'].mean()
yy['death/cases']=100*df.query("countriesAndTerritories == ['Singapore']")['deaths'].sum()/df.query("countriesAndTerritories == ['Singapore']")['cases'].sum()
yy
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020    390       2    SG                  SGP
# ...

# %%
uu=df.loc['South_Korea']

# %%
uu['cases/people']=100*df.query("countriesAndTerritories == ['South_Korea'] ")['cases'].sum()/df.query("countriesAndTerritories == ['South_Korea']")['popData2018'].mean()
uu['death/cases']=100*df.query("countriesAndTerritories == ['South_Korea']")['deaths'].sum()/df.query("countriesAndTerritories == ['South_Korea']")['cases'].sum()
uu
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020     62       6    KR                  KOR
# ...

# %%
ii=df.loc['United_States_of_America']

# %%
ii['cases/people']=100*df.query("countriesAndTerritories == ['United_States_of_America'] ")['cases'].sum()/df.query("countriesAndTerritories == ['United_States_of_America']")['popData2018'].mean()
ii['death/cases']=100*df.query("countriesAndTerritories == ['United_States_of_America']")['deaths'].sum()/df.query("countriesAndTerritories == ['United_States_of_America']")['cases'].sum()
ii
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020  28391    1831    US                  USA
# ...

# %%
pp=df.loc['United_Kingdom']

# %%
pp['cases/people']=100*df.query("countriesAndTerritories == ['United_Kingdom'] ")['cases'].sum()/df.query("countriesAndTerritories == ['United_Kingdom']")['popData2018'].mean()
pp['death/cases']=100*df.query("countriesAndTerritories == ['United_Kingdom']")['deaths'].sum()/df.query("countriesAndTerritories == ['United_Kingdom']")['cases'].sum()
pp
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             day  month  year  cases  deaths geoId countryterritoryCode  \
# dateRep
# 12/04/2020   12      4  2020   8719     917    UK                  GBR
# ...

# %%
plt.figure(figsize=(10,10))
oo.plot.scatter(x='cases/people', y='death/cases' , c='orange' ,s=2000 , title='china')
jj.plot.scatter(x='cases/people', y='death/cases' , c='red' , s=100 , title='thailand')
ww.plot.scatter(x='cases/people', y='death/cases' , c='gold' ,s=150 , title='Italy')
ee.plot.scatter(x='cases/people', y='death/cases' , c='green' ,s=300 , title='japan')
rr.plot.scatter(x='cases/people', y='death/cases' , c='aqua' ,s=200 , title='Germany')
tt.plot.scatter(x='cases/people', y='death/cases' , c='dodgerblue' ,s=2000 , title='India ')
yy.plot.scatter(x='cases/people', y='death/cases' , c='blue' ,s=20 , title='Singapore ')
uu.plot.scatter(x='cases/people', y='death/cases' , c='magenta' ,s=80 , title='South Korea ')
ii.plot.scatter(x='cases/people', y='death/cases' , c='purple' ,s=600 , title='USA')
pp.plot.scatter(x='cases/people', y='death/cases' , c='black' ,s=120 , title='UK')

# %%
gt['cases/people']=100*df.query("countriesAndTerritories == ['Thailand','China','Italy','Japan','Germany','India','Singapore','South_Korea','United_States_of_America','United_Kingdom','Iran'] ")['cases'].sum()/df.query("countriesAndTerritories == ['Thailand','China','Italy','Japan','Germany','India','Singapore','South_Korea','United_States_of_America','United_Kingdom','Iran']")['popData2018'].mean()
gt['death/cases']=100*df.query("countriesAndTerritories == ['Thailand','China','Italy','Japan','Germany','India','Singapore','South_Korea','United_States_of_America','United_Kingdom','Iran']")['deaths'].sum()/df.query("countriesAndTerritories == ['Thailand','China','Italy','Japan','Germany','India','Singapore','South_Korea','United_States_of_America','United_Kingdom','Iran']")['cases'].sum()
gt
# Out:
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SF4 JP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      day  month  year  cases  deaths geoId  \
# countriesAndTerritories  dateRep
# China                    12/04/2020   12      4  2020     93       0    CN
# ...

# %%
data = [('thai',df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()/df.query("countriesAndTerritories == ['Thailand']")['popData2018'].mean(),df.query("countriesAndTerritories == ['China']")['deaths'].sum()/df.query("countriesAndTerritories == ['China']")['cases'].sum())] 
label=['country','total','total1']
hh= pd.Dataframe.from_record(data, column=label)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-06e99d228a04> in <module>
#       1 data = [('thai',df.query("countriesAndTerritories == ['Thailand']")['cases'].sum()/df.query("countriesAndTerritories == ['Thailand']")['popData2018'].mean(),df.query("countriesAndTerritories == ['China']")['deaths'].sum()/df.query("countriesAndTerritories == ['China']")['cases'].sum())]
#       2 label=['country','total','total1']
# ----> 3 hh= pd.Dataframe.from_record(data, column=label)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
# Out:
#   File "<ipython-input-130-afbe2a8d31c7>", line 2
#     df.plot.scatter(x=['df.query("countriesAndTerritories == ['China'] ")['cases'].sum()'']/['df.query("countriesAndTerritories == ['China']")['popData2018'].mean(), y=df.query("countriesAndTerritories == ['China']")['deaths'].sum()/df.query("countriesAndTerritories == ['China']")['cases'].sum()'] , c='green' ,s=100 , title='s')
#                                                                    ^
# SyntaxError: invalid syntax
